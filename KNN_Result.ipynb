# %%
from numpy import random
import numpy 
import re
import os
import requests
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.request
import shutil
from time import sleep
import pandas as pd
from matplotlib.ticker import FormatStrFormatter
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from random import randint, randrange
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model, metrics, preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, f1_score
mainDB=pd.read_csv("Finalized_Data.csv")
secondaryDB=pd.read_csv("Just_Songs.csv")

# %%
#an attmpet to use KNN. It only yealded aproximately 60% accuracy, probably due to removign many columns and perhaps for an inccorect tool for the job
#Mannaged to increase it to 71.8 percent
y=mainDB["Next_Week_Shift"]
X=mainDB.drop(columns={"Next_Week_Shift","Artist_Name","Current_Date","Song_Name","Current_Day","Current_Month","Unnamed: 0","Number_Of_Previous_Hits"})
X["Last_Week"]=X["Last_Week"].replace({"-":0})
X["Last_Week"]=X["Last_Week"].astype('int64')
#X["Song_Name"]=codedDB["Song_Code"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf = KNeighborsClassifier(n_neighbors=4)
clf.fit(X_train, y_train)
i = 12
k = i
clf = KNeighborsClassifier(n_neighbors=k)
clf.fit(X_train, y_train)
    
y_pred=clf.predict(X_test)
print('Accuracy = ', metrics.accuracy_score(y_true = y_test, y_pred = y_pred))
mainDB.corr()
# Out:
# Accuracy =  0.7183911531618955
#                          Unnamed: 0  Current_Position  Relative_Movement  \
# Unnamed: 0                 1.000000          0.000226           0.159031
# Current_Position           0.000226          1.000000          -0.259922
# Relative_Movement          0.159031         -0.259922           1.000000
# Peak_Position              0.087408          0.812887          -0.030931
# Weeks_OnChart             -0.279841         -0.325138          -0.155351
# Number_Of_Previous_Hits   -0.191162         -0.049485          -0.086306
# Next_Week_Shift            0.174309          0.060129           0.335727
# Current_Year              -0.999843          0.000107          -0.158955
# Current_Month             -0.001636          0.000033          -0.008067
# Current_Day                0.000188         -0.000011           0.000533
#
#                          Peak_Position  Weeks_OnChart  \
# Unnamed: 0                    0.087408      -0.279841
# ...
